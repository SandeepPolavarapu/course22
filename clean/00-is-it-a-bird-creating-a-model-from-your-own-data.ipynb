# %% [markdown]
# ## Is it a bird?

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities
import os
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

if iskaggle:
    # !pip install -Uqq fastai

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
# Skip this cell if you already have duckduckgo_search installed
# !pip install -Uqq duckduckgo_search

# %%
# !pip install fastbook
# Import fastbook functions, in our case we'll be using: search_images_ddg
from fastbook import *
# create a function that will take an arbitrary search term and return a list of urls.
def search_images(term, max_images=30):
  print(f"Searching for '{term}'")
  # search_images_ddg comes from fastbook: https://github.com/fastai/fastbook/blob/master/utils.py#L45
  return search_images_ddg(term, max_images=max_images)
# Out:
# Requirement already satisfied: fastbook in c:\python311\lib\site-packages (0.0.29)
# Requirement already satisfied: pip in c:\python311\lib\site-packages (from fastbook) (24.2)
# Requirement already satisfied: packaging in c:\python311\lib\site-packages (from fastbook) (24.1)
# Requirement already satisfied: fastai>=2.6 in c:\python311\lib\site-packages (from fastbook) (2.7.16)
# Requirement already satisfied: graphviz in c:\python311\lib\site-packages (from fastbook) (0.20.3)
# Requirement already satisfied: pandas in c:\python311\lib\site-packages (from fastbook) (2.2.2)
# Requirement already satisfied: requests in c:\python311\lib\site-packages (from fastbook) (2.32.3)
# Requirement already satisfied: transformers in c:\python311\lib\site-packages (from fastbook) (4.44.0)
# Requirement already satisfied: datasets in c:\python311\lib\site-packages (from fastbook) (2.21.0)
# Requirement already satisfied: ipywidgets<8 in c:\python311\lib\site-packages (from fastbook) (7.8.3)
# Requirement already satisfied: sentencepiece in c:\python311\lib\site-packages (from fastbook) (0.2.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (1.5.55)
# Requirement already satisfied: torchvision>=0.11 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (0.19.0)
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (3.9.2)
# Requirement already satisfied: pyyaml in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (6.0.2)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (10.4.0)
# Requirement already satisfied: scikit-learn in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (1.5.1)
# Requirement already satisfied: scipy in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (1.14.0)
# Requirement already satisfied: spacy<4 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (3.7.5)
# Requirement already satisfied: torch<2.5,>=1.10 in c:\python311\lib\site-packages (from fastai>=2.6->fastbook) (2.4.0)
# Requirement already satisfied: comm>=0.1.3 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.8 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (3.6.8)
# Requirement already satisfied: ipython>=4.0.0 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (8.26.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\python311\lib\site-packages (from ipywidgets<8->fastbook) (1.1.9)
# Requirement already satisfied: filelock in c:\python311\lib\site-packages (from datasets->fastbook) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\python311\lib\site-packages (from datasets->fastbook) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\python311\lib\site-packages (from datasets->fastbook) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\python311\lib\site-packages (from datasets->fastbook) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in c:\python311\lib\site-packages (from datasets->fastbook) (4.66.5)
# Requirement already satisfied: xxhash in c:\python311\lib\site-packages (from datasets->fastbook) (3.5.0)
# Requirement already satisfied: multiprocess in c:\python311\lib\site-packages (from datasets->fastbook) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\python311\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->fastbook) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\python311\lib\site-packages (from datasets->fastbook) (3.10.4)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\python311\lib\site-packages (from datasets->fastbook) (0.24.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->fastbook) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests->fastbook) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->fastbook) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->fastbook) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas->fastbook) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas->fastbook) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas->fastbook) (2024.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\python311\lib\site-packages (from transformers->fastbook) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in c:\python311\lib\site-packages (from transformers->fastbook) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\python311\lib\site-packages (from transformers->fastbook) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (2.3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\python311\lib\site-packages (from aiohttp->datasets->fastbook) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python311\lib\site-packages (from huggingface-hub>=0.21.2->datasets->fastbook) (4.12.2)
# Requirement already satisfied: decorator in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.18.0)
# Requirement already satisfied: stack-data in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.3)
# Requirement already satisfied: colorama in c:\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->fastbook) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.12.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.8.2)
# Requirement already satisfied: jinja2 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.4)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.4.0)
# Requirement already satisfied: sympy in c:\python311\lib\site-packages (from torch<2.5,>=1.10->fastai>=2.6->fastbook) (1.13.2)
# Requirement already satisfied: networkx in c:\python311\lib\site-packages (from torch<2.5,>=1.10->fastai>=2.6->fastbook) (3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\python311\lib\site-packages (from widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (7.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\python311\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\python311\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (3.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\python311\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: language-data>=1.2 in c:\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (4.2.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (6.4.1)
# Requirement already satisfied: wcwidth in c:\python311\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (2.20.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.6->fastbook) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.6->fastbook) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python311\lib\site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.5)
# Requirement already satisfied: executing>=1.2.0 in c:\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.4.1)
# Requirement already satisfied: pure-eval in c:\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python311\lib\site-packages (from sympy->torch<2.5,>=1.10->fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.0.13)
# Requirement already satisfied: pyzmq>=24 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (26.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\python311\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\python311\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\python311\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\python311\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.2.5)
# Requirement already satisfied: babel>=2.10 in c:\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (4.23.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (3.0.0)
# Requirement already satisfied: wrapt in c:\python311\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\python311\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.8.5)
# Requirement already satisfied: nest-asyncio in c:\python311\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.6.0)
# Requirement already satisfied: psutil in c:\python311\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (6.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (306)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (6.1.0)
# Requirement already satisfied: defusedxml in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.20.0)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: fqdn in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: isoduration in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (3.0.0)
# Requirement already satisfied: uri-template in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.5)
# Requirement already satisfied: pycparser in c:\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.8->ipywidgets<8->fastbook) (2.9.0.20240316)

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# Searching for 'bird photos'
# 'http://3.bp.blogspot.com/-i0B5H0Kcbv4/U86hbmU5vII/AAAAAAAAC_4/PH-eW0O1i94/s1600/lorikeets.jpg'

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x190>

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for 'forest photos'
# <PIL.Image.Image image mode=RGB size=256x144>

# %%
searches = 'forest','bird'
path = Path('bird_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)  # Pause between searches to avoid over-loading server
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'forest photo'
# Searching for 'forest sun photo'
# Searching for 'forest shade photo'
# Searching for 'bird photo'
# Searching for 'bird sun photo'
# Searching for 'bird shade photo'

# %% [markdown]
# ## Step 2: Train our model

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 10

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path)

dls.show_batch(max_n=6)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\spodev/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:11<00:00, 4.10MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.431443</td>
#       <td>0.761409</td>
#       <td>0.375000</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.503497</td>
#       <td>0.266207</td>
#       <td>0.125000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.331430</td>
#       <td>0.036963</td>
#       <td>0.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.235053</td>
#       <td>0.010604</td>
#       <td>0.000000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
# This is a: bird.
# Probability it's a bird: 1.0000
